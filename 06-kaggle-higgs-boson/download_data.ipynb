# %%
# !pip install kaggle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 1.3 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 1.8 MB/s eta 0:00:00148.5 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 123.6 kB/s eta 0:00:001m118.9 kB/s eta 0:00:01
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.11-py3-none-any.whl size=114542 sha256=0b9fb7f6d5a7da660a9b49c44d195f660d2fa7bb68644f78b2918e836a9e5b2c
#   Stored in directory: /home/xqft/.cache/pip/wheels/d8/bc/2a/f7bb3ea8dbbf6be2f2c4a1557a132e78a3b5e0e76a8652166a
# Successfully built kaggle
# ...

# %% [markdown]
# Luego es necesario tener el archivo kaggle.json con un access key

# %%
# !mkdir -p higgs-boson \
&& cd higgs-boson \
&& kaggle competitions download -c higgs-boson \
&& unzip higgs-boson.zip \
&& unzip random_submission.zip \
&& unzip test.zip \
&& unzip training.zip \
&& rm -rf *.zip
# Out:
# ...
#  96%|████████████████████████████████████▍ | 52.0M/54.3M [00:02<00:00, 30.0MB/s]
# 100%|██████████████████████████████████████| 54.3M/54.3M [00:02<00:00, 20.6MB/s]
# Archive:  higgs-boson.zip
#   inflating: HiggsBosonCompetition_AMSMetric_rev1.py
#   inflating: random_submission.zip
#   inflating: test.zip
#   inflating: training.zip
# Archive:  random_submission.zip
#   inflating: random_submission.csv
# Archive:  test.zip
#   inflating: test.csv
# Archive:  training.zip
#   inflating: training.csv
